# %% [markdown]
# # AUTHOR: ANIKET PATIL
#
# # Prodigy Tech Internship : Data Science
#
# # Task 1: Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %% [markdown]
# # 1. Importing Necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Data cleaning and Exploratory data analysis

# %%
df = pd.read_csv('./bank.csv')
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %% [markdown]
# ## Check the unique values

# %%
df['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %% [markdown]
# ## Understanding values
# Figuring out the values that are present in the dataset. If there are null values we shall remove them. Its handy to check the data type of the data columns and values.

# %%
df = df.iloc[:, :-1]
df.info()

df.isna().count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df['Country Code'].nunique()
# Out:
# 266

# %%
df['Country Name'].nunique()
# Out:
# 266

# %% [markdown]
# # 3. Visualisation
# Since the no. of region and countries is around 266. Visualising these no. of countries is impractical. For which we opt to visualise by region and by continents.

# %% [markdown]
# ## Visualisation of South Asia

# %%
south_asia_population = df[df["Country Name"] == 'South Asia (IDA & IBRD)']
years = south_asia_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = south_asia_population.iloc[:, 5:].squeeze()
country_name = south_asia_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of South Asia')
plt.xlabel('Years')
plt.ylabel('Population in Billions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of West bank and Gaza population

# %%
west_bank_and_gaza_population = df[df["Country Name"] == 'West Bank and Gaza']
years = west_bank_and_gaza_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = west_bank_and_gaza_population.iloc[:, 5:].squeeze()
country_name = west_bank_and_gaza_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of West Bank and Gaza')
plt.xlabel('Years')
plt.ylabel('Population in Hundred Millions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of Sub-Saharan Africa

# %%
sub_saharan_africa_population = df[df["Country Name"] == 'Sub-Saharan Africa']
years = sub_saharan_africa_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = sub_saharan_africa_population.iloc[:, 5:].squeeze()
country_name = sub_saharan_africa_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of Sub-Saharan Africa')
plt.xlabel('Years')
plt.ylabel('Population in Hundred Millions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of Sub-Saharan Africa (excluding high income)

# %%
sub_saharan_africa_ex_high_income_population = df[df["Country Name"] == 'Sub-Saharan Africa (excluding high income)']
years = sub_saharan_africa_ex_high_income_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = sub_saharan_africa_ex_high_income_population.iloc[:, 5:].squeeze()
country_name = sub_saharan_africa_ex_high_income_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of Sub-Saharan Africa excluding high income')
plt.xlabel('Years')
plt.ylabel('Population in Hundred Millions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of European Union population

# %%
european_union_population = df[df["Country Name"] == 'European Union']
years = european_union_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = european_union_population.iloc[:, 5:].squeeze()
country_name = european_union_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of European Union')
plt.xlabel('Years')
plt.ylabel('Population in Hundred Millions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of East Asia & Pacific population

# %%
east_asia_and_pacific_population = df[df["Country Name"] == 'East Asia & Pacific']
years = east_asia_and_pacific_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = east_asia_and_pacific_population.iloc[:, 5:].squeeze()
country_name = east_asia_and_pacific_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of East Asia & Pacific')
plt.xlabel('Years')
plt.ylabel('Population in Billions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of Central Europe and The Baltics

# %%
central_europe_and_the_baltics_population = df[df["Country Name"] == 'Central Europe and the Baltics']
years = central_europe_and_the_baltics_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = central_europe_and_the_baltics_population.iloc[:, 5:].squeeze()
country_name = central_europe_and_the_baltics_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of Central Europe and The Baltics')
plt.xlabel('Years')
plt.ylabel('Population in Hundred Millions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of Arab world population

# %%
arab_world_population = df[df["Country Name"] == 'Arab World']
years = arab_world_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = arab_world_population.iloc[:, 5:].squeeze()
country_name = arab_world_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of  Arab World')
plt.xlabel('Years')
plt.ylabel('Population in Hundred Millions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of Africa Western and Central population

# %%
africa_western_and_central_population = df[df["Country Name"] == 'Africa Western and Central']
years = africa_western_and_central_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = africa_western_and_central_population.iloc[:, 5:].squeeze()
country_name = africa_western_and_central_population.iloc[0]['Country Name']

plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of  Africa Western and Central')
plt.xlabel('Years')
plt.ylabel('Population in Hundred Millions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ## Visualisation of Latin America Population

# %%
latin_america_population = df[df["Country Name"] == 'Latin America & the Caribbean (IDA & IBRD countries)']
years = latin_america_population.columns[5:]
years = years.astype(str).tolist()  
population_over_period = latin_america_population.iloc[:, 5:].squeeze()
country_name = latin_america_population.iloc[0]['Country Name']

# %%
plt.figure(figsize=(10, 2))
plt.bar(years, population_over_period, color='blue', alpha=0.7)
plt.title('Population of Latin America Population Including Caribbean')
plt.xlabel('Years')
plt.ylabel('Population in Hundred Millions')
plt.grid(axis='y')
plt.xticks(years, rotation=90)
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Conclusion
# As we can see through visualisation that the developing countries have upward trend of population. That is indicating positive and exponential growth of population. Where as developed countries have maintained their population.
